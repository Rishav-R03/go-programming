# %% [markdown]
# This 60-day curriculum focuses on backend fundamentals, low-level database mechanics, high-level system design, and production engineering.
#
# To get noticed by startups, every phase is paired with an actionable public showcase task (GitHub repos, technical blog posts, or system architecture breakdowns) to build a proof-of-work portfolio online.
#
# ---
#
# ### **Phase 1: Advanced Networking & API Protocol Engineering (Days 1–15)**
#
# | Days | Concept / Focus Area | Topics & System Design Mechanics | Public Showcase Deliverable |
# | --- | --- | --- | --- |
# | **1–3** | **Network Protocols & Socket I/O** | TCP/UDP state machines, Three-Way Handshakes, TLS 1.3 termination, Socket multiplexing (`epoll`/`kqueue`). | **Blog/Post:** Write a deep-dive breakdown on *"What actually happens at the OS network stack level during a single HTTPS request."* |
# | **4–6** | **Production API Design** | RESTful constraints, gRPC over HTTP/2, Protocol Buffers (`protobuf`), API Gateway routes, Input validation. | **GitHub Code:** Build a microservice with dual endpoints (REST vs gRPC) using `protobuf` and publish a latency benchmark comparison. |
# | **7–9** | **Authentication & Security** | JWT lifecycle, Refresh token rotation, OAuth 2.0 PKCE flow, Password hashing (Argon2/bcrypt), CORS. | **GitHub Code:** Create a reusable, production-ready Auth Service repo with stateless JWT rotation and Redis token blacklisting. |
# | **10–12** | **Rate Limiting & Traffic Shaping** | Token Bucket, Leaky Bucket, Sliding Window Log algorithms, Rate-limiting headers (`X-RateLimit-*`). | **GitHub Code:** Build an HTTP Rate Limiting Middleware implementing sliding-window algorithms backed by atomic Redis scripts. |
# | **13–15** | **Idempotency & Retries** | API Idempotency keys, Exponential backoff + Jitter, Anti-Thundering-Herd strategies. | **Tech Article:** Publish a code tutorial on *"How to guarantee Exactly-Once API execution using Redis idempotency locks."* |
#
# ---
#
# ### **Phase 2: Database Scalability, Storage Engines & Caching (Days 16–30)**
#
# | Days | Concept / Focus Area | Topics & System Design Mechanics | Public Showcase Deliverable |
# | --- | --- | --- | --- |
# | **16–18** | **Database Storage Mechanics** | B-Trees vs LSM-Trees, Write-Ahead Logging (WAL), Page buffers, Read/Write amplification trade-offs. | **Blog/Post:** Create a visual infographic comparing *"When to pick B-Tree (Postgres) vs LSM-Tree (Cassandra/RocksDB)"*. |
# | **19–21** | **Advanced Indexing & Optimization** | Composite key indexing, Leftmost prefix rule, Index Only Scans, Query planner analysis (`EXPLAIN ANALYZE`). | **GitHub Code:** Post a performance optimization case study repo showing a query runtime dropped from 1200ms to 4ms via proper indexing. |
# | **22–24** | **Replication & High Availability** | Primary-Replica, Multi-Primary, Synchronous vs Asynchronous replication, Replication Lag, Failover strategies. | **System Diagram:** Draw an Architecture Diagram illustrating high-availability failover with PgBouncer, Read Replicas, and VIPs. |
# | **25–27** | **Sharding & Partitioning** | Range vs Hash partitioning, Consistent Hashing algorithm, Cross-shard joins, Distributed transactions (2PC). | **Interactive Code:** Implement a working **Consistent Hashing Ring with Virtual Nodes** in code and publish it as an open-source library. |
# | **28–30** | **Caching Systems & Strategies** | Cache-Aside, Write-Through, Write-Back, Cache Stampede/Avalanche, Mutex locking vs Probabilistic early expiration. | **GitHub Code:** Create a production-safe Cache Manager package that mitigates Cache Stampede using singleflight request coalescing. |
#
# ---
#
# ### **Phase 3: Asynchronous Systems & Distributed Architecture (Days 31–45)**
#
# | Days | Concept / Focus Area | Topics & System Design Mechanics | Public Showcase Deliverable |
# | --- | --- | --- | --- |
# | **31–33** | **Message Queues & Event-Driven Systems** | RabbitMQ vs Apache Kafka, AMQP protocols, Log-based message brokers, Consumer groups, Offsets. | **GitHub Code:** Build an Event-Driven notification system handling email/SMS dispatch asynchronously with dead-letter queue (DLQ) support. |
# | **34–36** | **Consistency Models & CAP/PACELC** | CAP Theorem, Eventual vs Strong Consistency, Read-Your-Own-Writes, Linearizability vs Serializability. | **Blog/Post:** Write a system trade-off analysis titled *"Navigating PACELC: How Stripe balances data consistency vs availability in financial flows."* |
# | **37–39** | **Distributed Locking & Consensus** | Distributed Locks (Redis Redlock, Etcd/Zookeeper), Fencing Tokens, Raft consensus algorithm basics. | **Tech Article:** Publish a post explaining *"The Fencing Token Problem: Why naive Redis locks can corrupt data and how to fix it."* |
# | **40–42** | **Resiliency & Fault Tolerance** | Circuit Breaker pattern, Bulkhead pattern, Graceful Degradation, Health/Liveness probes. | **GitHub Code:** Implement a lightweight, zero-dependency Circuit Breaker package with configurable state thresholds (Closed, Open, Half-Open). |
# | **43–45** | **Microservices vs Monoliths** | Service Discovery, Distributed Tracing (OpenTelemetry), Saga Pattern (Choreography vs Orchestration). | **System Design Document:** Write a full RFC/Architecture Design Document for a Distributed Saga Pattern handling an e-commerce checkout flow. |
#
# ---
#
# ### **Phase 4: Production DevOps, Observability & Real-World System Design (Days 46–60)**
#
# | Days | Concept / Focus Area | Topics & System Design Mechanics | Public Showcase Deliverable |
# | --- | --- | --- | --- |
# | **46–48** | **Containerization & Orchestration** | Docker multi-stage builds, Distroless images, Container networking, Kubernetes basics (Pods, Deployments, Services). | **GitHub Code:** Create a repository with hardened Dockerfiles and Docker Compose files for a microservices cluster (App + DB + Redis + Kafka). |
# | **49–51** | **Observability & Telemetry** | Structured JSON logging, Prometheus metrics (`Counter`, `Gauge`, `Histogram`), Grafana dashboards, Distributed Tracing. | **Live Dashboard:** Deploy an application exposing `/metrics` with a pre-configured Grafana dashboard monitoring P99 request latency and DB connection pools. |
# | **52–54** | **System Design Problem 1** | **Design a URL Shortener (TinyURL)**: Base62 encoding, KGS (Key Generation Service), Redis caching, DB sharding. | **System Design Case Study:** Publish a complete architecture diagram and technical design doc on GitHub/LinkedIn covering trade-offs and capacity planning. |
# | **55–57** | **System Design Problem 2** | **Design a Distributed Rate Limiter / API Gateway**: Centralized vs Local caching, Race conditions, Multi-region deployment. | **System Design Case Study:** Publish an in-depth HLD/LLD breakdown covering edge rate-limiting for millions of daily active users. |
# | **58–60** | **System Design Problem 3** | **Design a Real-Time Notification System**: WebSockets, Server-Sent Events (SSE), Push Notifications, Message Queues. | **Portfolio Showcase:** Publish a public GitHub repository containing a real-time notification engine with an accompanying System Architecture Readme. |
#
# ---
#
# ### **Online Showcase & Personal Branding Strategy**
#
# To translate learning into job offers, treat public work like an active technical portfolio:
#
# 1. **GitHub Readme Portfolio Engine:** For every project repo, avoid bare code. Add an architectural system diagram (using *Excalidraw* or *Mermaid.js*), load testing results (`k6` / `Vegeta`), and a section titled *"Trade-offs & Edge Cases Handled"*.
# 2. **Weekly Engineering Articles:** Convert complex concepts learned into concise articles published on Medium or Hashnode (e.g., *"How I Reduced Database Contention by 80% Using Optimistic Locking"*).
# 3. **LinkedIn Proof-of-Work Logs:** Every 3–5 days, post a short technical write-up detailing a problem solved, complete with code snippets, terminal benchmarks, or architectural diagrams.

# %% [markdown]
# # Top Interview Questions
#
# These **28 core backend engineering questions** account for approximately 80% of what interviewers repeatedly test across Mid-to-Senior Backend, Systems, and API interviews. They are grouped by functional domain along with the exact core concepts you are expected to articulate.
#
# ---
#
# ### 1. Networking, Protocols & API Design
#
# * **1. What happens under the hood when a client makes an HTTPS request to a server?**
# * *Concepts:* DNS resolution, TCP 3-way handshake (`SYN`, `SYN-ACK`, `ACK`), TLS/SSL handshake (key exchange and symmetric encryption), and HTTP layer request/response cycle.
#
#
# * **2. How do REST, gRPC, and GraphQL compare, and when would you choose one over the others?**
# * *Concepts:* REST (over-fetching/under-fetching, HTTP verbs), gRPC (HTTP/2, Protobufs, low-latency inter-service communication), GraphQL (single endpoint, client-defined schemas).
#
#
# * **3. How do you handle API idempotency, especially for payment or order creation endpoints?**
# * *Concepts:* `Idempotency-Key` headers, distributed locks (Redis), atomic database constraints, and preventing double-spend/duplicate entries.
#
#
# * **4. What are the core strategies for API Rate Limiting, and how do you implement them at scale?**
# * *Concepts:* Token Bucket, Leaky Bucket, Sliding Window Log algorithm, distributed caching (Redis counters), and API Gateways.
#
#
# * **5. How do stateful sessions, JWTs, and OAuth2/OIDC differ for authentication and authorization?**
# * *Concepts:* Session cookies vs. stateless JWTs (token revocation issues, expiration, signature verification), OAuth2 flows, and authorization models (RBAC/ABAC).
#
#
#
# ---
#
# ### 2. Databases & Storage Mechanics
#
# * **6. How do B-Trees and B+ Trees work, and why are they used for database indexing instead of Binary Search Trees or Hash Tables?**
# * *Concepts:* Disk I/O reduction, block/page storage, sequential read performance, and range query efficiency in relational databases.
#
#
# * **7. What are the ACID properties, and how do database isolation levels balance correctness vs. performance?**
# * *Concepts:* Atomicity, Consistency, Isolation, Durability. Isolation levels (Read Uncommitted, Read Committed, Repeatable Read, Serializable) and concurrency anomalies (Dirty Read, Non-repeatable Read, Phantom Read).
#
#
# * **8. What is the CAP Theorem, and how does PACELC expand upon it?**
# * *Concepts:* Consistency vs. Availability during network Partitions (CAP); Else (when no partition exists), Latency vs. Consistency (PACELC).
#
#
# * **9. How do you identify, optimize, and eliminate slow database queries?**
# * *Concepts:* Query execution plans (`EXPLAIN ANALYZE`), avoiding `N+1` query problems, eliminating `FULL TABLE SCANS`, covering indexes, and composite index ordering.
#
#
# * **10. When should you choose a Relational (SQL) database over a NoSQL database (Document, Key-Value, Columnar, Graph)?**
# * *Concepts:* Structured vs. unstructured data, strict ACID transactional needs vs. horizontal scalability, write throughput, and flexible schemas.
#
#
# * **11. How do Optimistic and Pessimistic locking work to handle concurrent database updates?**
# * *Concepts:* Pessimistic (`SELECT ... FOR UPDATE` row locks) vs. Optimistic (version/timestamp checks), lock contention, and preventing race conditions.
#
#
#
# ---
#
# ### 3. Caching & Performance Optimization
#
# * **12. What are the standard Cache Eviction Policies and Cache Invalidation Strategies?**
# * *Concepts:* Eviction (LRU, LFU, FIFO); Invalidation patterns (Cache-Aside, Write-Through, Write-Behind, Read-Through).
#
#
# * **13. How do you mitigate the Cache Avalanche, Cache Stampede (Thundering Herd), and Cache Penetration problems?**
# * *Concepts:* TTL jitter, distributed locking/single-flight patterns, mutexes, storing null values for missing keys, and Bloom Filters.
#
#
# * **14. How does Redis achieve high throughput despite operating on a single-threaded execution model for commands?**
# * *Concepts:* Non-blocking I/O multiplexing (`epoll`), execution in memory, avoiding thread context switching overhead, and atomic operations.
#
#
#
# ---
#
# ### 4. Distributed Systems & Messaging Architecture
#
# * **15. How do Message Queues (RabbitMQ/SQS) and Distributed Event Logs (Kafka) differ?**
# * *Concepts:* Push vs. Pull models, transient message deletion vs. append-only immutable logs with offset retention, and worker queues vs. stream processing.
#
#
# * **16. How do you guarantee "At-Least-Once", "At-Most-Once", and "Exactly-Once" message delivery?**
# * *Concepts:* Producer acknowledgements, consumer offset commits, retry policies, dead-letter queues (DLQ), and consumer-side idempotent processing.
#
#
# * **17. How does the Transactional Outbox Pattern solve the dual-write problem between a Database and a Message Broker?**
# * *Concepts:* Atomic database commits, decoupling event emission from business logic, and Change Data Capture (CDC) / tailing transaction logs.
#
#
# * **18. How do horizontal scaling strategies like Database Sharding and Consistent Hashing work?**
# * *Concepts:* Partition keys, hotspots, rehashing problems on cluster resizing, and Consistent Hashing rings with virtual nodes.
#
#
# * **19. What is the Distributed Saga Pattern, and how does it replace Two-Phase Commit (2PC) in Microservices?**
# * *Concepts:* Choreography vs. Orchestration, compensating transactions, eventual consistency, and avoiding long-lived distributed database locks.
#
#
#
# ---
#
# ### 5. Concurrency & Execution Mechanics
#
# * **20. What is the fundamental difference between a Process and a Thread?**
# * *Concepts:* Shared memory space vs. isolated address spaces, context switching overhead, CPU scheduling, and Inter-Process Communication (IPC).
#
#
# * **21. How do Concurrency and Parallelism differ, and how does Asynchronous Non-blocking I/O work?**
# * *Concepts:* Task interleaving vs. simultaneous multi-core execution; OS event loops (`epoll`, `kqueue`) and yielding execution during thread I/O wait times.
#
#
# * **22. What are Race Conditions, Deadlocks, and Starvation, and how do you prevent them?**
# * *Concepts:* Mutexes, Semaphores, Atomic variables, lock hierarchy enforcement, and avoiding nested resource acquisition.
#
#
#
# ---
#
# ### 6. Observability, Security & Production Readiness
#
# * **23. How do you design for High Availability and Fault Tolerance?**
# * *Concepts:* Circuit Breakers (Resilience4j/Hystrix), retries with exponential backoff and jitter, graceful degradation, and load shedding.
#
#
# * **24. What are the key metrics for monitoring a production backend system?**
# * *Concepts:* The 4 Golden Signals (Latency, Traffic, Errors, Saturation), RED method (Rate, Errors, Duration), distributed tracing (Trace IDs, Span IDs), and structured logging.
#
#
# * **25. How do you prevent OWASP Top 10 security vulnerabilities on the backend?**
# * *Concepts:* SQL Injection (parameterized queries), Cross-Site Scripting (XSS), Cross-Site Request Forgery (CSRF), Broken Object Level Authorization (BOLA/IDOR), and input sanitization.
#
#
# * **26. How do zero-downtime deployment strategies work?**
# * *Concepts:* Blue-Green deployments, Canary releases, Rolling updates, and backward-compatible database schema migrations (Expand-Contract pattern).
#
#
#
# ---
#
# ### 7. Core System Design Scenarios
#
# * **27. How would you design a Rate Limiter or URL Shortener (e.g., Bitly)?**
# * *Concepts:* High-throughput reads/writes, unique hash generation (Base62 vs. pre-generated key pools), Redis caching, DB selection, and race conditions.
#
#
# * **28. How would you design an Event-Driven Notification System or Web Crawler at scale?**
# * *Concepts:* Decoupled message queues, worker pools, distributed deduplication, rate-limiting external targets, and prioritizing queues.

# %% [markdown]
# **Core Request & Routing**
#
# * **Request Context & Deadlines:** Learn `context.Context` for propagation, request cancellation, and setting timeouts (`context.WithTimeout`) so slow upstream services don't freeze server goroutines.
# * **Input Validation & Sanitization:** Validate struct payloads (using tags or custom validators) before processing to prevent bad data or injection attacks.
# * **Idiomatic Error Handling:** Standardize error wrapping with `fmt.Errorf("%w", err)` and construct unified JSON error responses across your API instead of returning raw internal errors.
#
# **Data Persistence & Transactions**
#
# * **Database Connections & Pooling:** Manage database pools with `database/sql` (`SetMaxOpenConns`, `SetMaxIdleConns`), understand connection lifetimes, and prevent connection starvation.
# * **Database Migrations:** Schema version control using tools like `golang-migrate` to execute up/down migration files deterministically across environments.
# * **Database Transactions & Isolation:** Execute multi-step atomic operations using `db.BeginTx()`, handling rollback on errors and understanding read/write lock implications.
# * **Data Access Patterns (Repository Pattern):** Decouple business logic from persistence code using Go interfaces to facilitate unit testing and database swapping.
#
# **Caching & State Management**
#
# * **In-Memory & Distributed Caching:** Implement Cache-Aside and Write-Through patterns using Redis (`go-redis`) for expensive queries and session storage.
# * **Cache Invalidation & TTL:** Set Time-To-Live strategies and cache invalidation mechanics to avoid stale data issues.
#
# **Security & Protection**
#
# * **Rate Limiting & Throttling:** Implement Token Bucket or Leaky Bucket algorithms (using `golang.org/x/time/rate` or Redis) to protect endpoints from abuse and DoS attacks.
# * **Secrets Management & Config:** Load environment variables securely into structured Go configs without hardcoding credentials in repository code.
#
# **Asynchronous Processing & Communication**
#
# * **Worker Pools & Background Jobs:** Utilize Go channels and goroutines to construct bounded worker pools for heavy, non-blocking background tasks (e.g., sending emails, processing uploads).
# * **Message Queues & Event-Driven Architecture:** Integrate message brokers like RabbitMQ or NATS to decouple services and process asynchronous job queues safely.
#
# **Observability & Operations**
#
# * **Structured Logging:** Move past `log.Println` to structured JSON logging using Go's standard `log/slog` library, appending contextual key-value pairs (trace IDs, user IDs).
# * **Distributed Tracing & Request Correlation:** Generate or propagate correlation IDs (`X-Request-ID`) across incoming requests and outgoing downstream calls to trace execution paths.
# * **Metrics Collection:** Instrument HTTP server endpoints using Prometheus (`prometheus/client_golang`) to measure request latency (histograms), error rates, and concurrent connection counters.
# * **Graceful Shutdown:** Capture OS signals (`SIGINT`, `SIGTERM`) to stop accepting new HTTP connections and wait for in-flight requests and background workers to clean up before process exit.

# %% [markdown]
# Your current roadmap (DSA + CS fundamentals + Go + PostgreSQL + Docker + Redis + RabbitMQ + Prometheus) is already quite aligned with what Series A–C startups want.
#
# The adjustment I would make is this:
#
# **Don't study technologies in isolation anymore.**
# Every week should answer a startup question:
#
# > "Can this person own a backend service in production with minimal supervision?"
#
# The 90-day plan below is optimized for that.
#
# ---
#
# # 90-Day Backend Engineering Plan (2026 Startup Focus)
#
# ### Time Budget
#
# | Day      | Hours   |
# | -------- | ------- |
# | Weekdays | 3 hrs   |
# | Saturday | 5-6 hrs |
# | Sunday   | 4-5 hrs |
#
# Daily split:
#
# * 45 min DSA
# * 60 min Fundamentals / System Design
# * 60-90 min Project Work
#
# ---
#
# # Month 1 (Days 1-30)
#
# ## Goal: Build a Production-Ready Core Service
#
# Project:
# **Order Processing System**
#
# Stack:
#
# * Go
# * PostgreSQL
# * Docker
# * Redis
# * RabbitMQ
#
# ---
#
# # Week 1
#
# ## PostgreSQL + Go API Foundations
#
# ### Day 1
#
# Study:
#
# * PostgreSQL architecture
# * Tables
# * Primary keys
# * Indexes
#
# DSA:
#
# * Arrays
# * Hashmaps
#
# Build:
#
# * Create database schema for:
#
#   * users
#   * products
#   * orders
#
# ---
#
# ### Day 2
#
# Study:
#
# * B-tree indexes
# * Query execution basics
#
# DSA:
#
# * Two pointers
#
# Build:
#
# * Seed data script
# * Run EXPLAIN on queries
#
# ---
#
# ### Day 3
#
# Study:
#
# * Transactions
# * ACID
#
# DSA:
#
# * Sliding window
#
# Build:
#
# * Create order transaction flow
#
# ---
#
# ### Day 4
#
# Study:
#
# * Isolation levels
#
# DSA:
#
# * Prefix sums
#
# Build:
#
# * Simulate concurrent order placement
#
# ---
#
# ### Day 5
#
# Study:
#
# * SQL optimization
#
# DSA:
#
# * Binary search
#
# Build:
#
# * Benchmark indexed vs non-indexed queries
#
# ---
#
# ### Day 6
#
# Study:
#
# * Go project structure
#
# Build:
#
# * REST API
# * CRUD endpoints
#
# Review:
#
# * Read generated code critically
#
# ---
#
# ### Day 7
#
# Study:
#
# * Error handling
# * Middleware
#
# Build:
#
# * Validation layer
# * Centralized error handling
#
# ---
#
# # Week 2
#
# ## Docker + Redis
#
# ### Day 8
#
# Study:
#
# * Docker fundamentals
#
# Build:
#
# * Dockerize service
#
# ---
#
# ### Day 9
#
# Study:
#
# * Docker networking
#
# Build:
#
# * Compose setup
#
# ---
#
# ### Day 10
#
# Study:
#
# * Redis fundamentals
#
# Build:
#
# * Product cache
#
# ---
#
# ### Day 11
#
# Study:
#
# * Cache invalidation
#
# Build:
#
# * Cache eviction strategy
#
# ---
#
# ### Day 12
#
# Study:
#
# * Redis persistence
#
# Build:
#
# * Rate limiter
#
# ---
#
# ### Day 13
#
# Study:
#
# * Linux basics
#
# Commands:
#
# * ps
# * top
# * netstat
# * journalctl
#
# Build:
#
# * Debug running containers
#
# ---
#
# ### Day 14
#
# Weekend Review
#
# Task:
#
# * Ask Claude/Cursor to rewrite service
# * Perform full code review
# * Identify:
#
#   * SQL issues
#   * Error handling gaps
#   * Security risks
#
# ---
#
# # Week 3
#
# ## RabbitMQ + Async Systems
#
# ### Day 15
#
# Study:
#
# * Messaging fundamentals
#
# Build:
#
# * RabbitMQ setup
#
# ---
#
# ### Day 16
#
# Study:
#
# * Queues
# * Exchanges
#
# Build:
#
# * Order events
#
# ---
#
# ### Day 17
#
# Study:
#
# * Consumers
#
# Build:
#
# * Analytics consumer
#
# ---
#
# ### Day 18
#
# Study:
#
# * Retry strategies
#
# Build:
#
# * Dead letter queue
#
# ---
#
# ### Day 19
#
# Study:
#
# * Idempotency
#
# Build:
#
# * Duplicate message protection
#
# ---
#
# ### Day 20
#
# Study:
#
# * Event-driven architecture
#
# Build:
#
# * Order completed workflow
#
# ---
#
# ### Day 21
#
# Review Day
#
# Draw:
#
# * Full architecture diagram
#
# ---
#
# # Week 4
#
# ## Networking + APIs
#
# ### Day 22
#
# Study:
#
# * HTTP internals
#
# Build:
#
# * Request logging
#
# ---
#
# ### Day 23
#
# Study:
#
# * REST best practices
#
# Refactor:
#
# * API responses
#
# ---
#
# ### Day 24
#
# Study:
#
# * gRPC fundamentals
#
# Build:
#
# * Small gRPC endpoint
#
# ---
#
# ### Day 25
#
# Study:
#
# * HTTP vs gRPC
#
# Write:
#
# * Tradeoff document
#
# ---
#
# ### Day 26
#
# Study:
#
# * Authentication
#
# Build:
#
# * JWT auth
#
# ---
#
# ### Day 27
#
# Study:
#
# * Authorization
#
# Build:
#
# * Role checks
#
# ---
#
# ### Day 28
#
# Study:
#
# * Security basics
#
# Build:
#
# * Input sanitization
#
# ---
#
# ### Day 29
#
# System Design Day
#
# Design:
#
# * URL Shortener
#
# ---
#
# ### Day 30
#
# Project Milestone
#
# Deliver:
#
# * README
# * Architecture diagrams
# * Docker setup
# * API docs
#
# ---
#
# # Month 2 (Days 31-60)
#
# ## Goal: Production Thinking + Observability
#
# ---
#
# # Week 5
#
# ## Monitoring
#
# ### Day 31
#
# Study:
#
# * Observability pillars
#
# Build:
#
# * Structured logging
#
# ---
#
# ### Day 32
#
# Study:
#
# * Prometheus
#
# Build:
#
# * Metrics endpoint
#
# ---
#
# ### Day 33
#
# Build:
#
# * Request counters
#
# ---
#
# ### Day 34
#
# Build:
#
# * Latency metrics
#
# ---
#
# ### Day 35
#
# Build:
#
# * Queue metrics
#
# ---
#
# ### Day 36
#
# Build:
#
# * Business metrics
#
# ---
#
# ### Day 37
#
# Review Dashboard
#
# ---
#
# # Week 6
#
# ## Testing
#
# ### Day 38
#
# Study:
#
# * Unit testing
#
# Build tests
#
# ---
#
# ### Day 39
#
# Mock dependencies
#
# ---
#
# ### Day 40
#
# Integration tests
#
# ---
#
# ### Day 41
#
# Database testing
#
# ---
#
# ### Day 42
#
# API testing
#
# ---
#
# ### Day 43
#
# Load testing theory
#
# ---
#
# ### Day 44
#
# k6 setup
#
# ---
#
# # Week 7
#
# ## Performance
#
# ### Day 45
#
# Study:
#
# * Profiling
#
# ---
#
# ### Day 46
#
# pprof
#
# ---
#
# ### Day 47
#
# Memory leaks
#
# ---
#
# ### Day 48
#
# CPU bottlenecks
#
# ---
#
# ### Day 49
#
# Connection pools
#
# ---
#
# ### Day 50
#
# Database optimization
#
# ---
#
# ### Day 51
#
# Performance report
#
# ---
#
# # Week 8
#
# ## Cloud + CI/CD
#
# ### Day 52
#
# GitHub Actions
#
# ---
#
# ### Day 53
#
# Build pipeline
#
# ---
#
# ### Day 54
#
# Test pipeline
#
# ---
#
# ### Day 55
#
# Docker registry
#
# ---
#
# ### Day 56
#
# Deploy VM
#
# ---
#
# ### Day 57
#
# Nginx basics
#
# ---
#
# ### Day 58
#
# Reverse proxy setup
#
# ---
#
# ### Day 59
#
# Deployment automation
#
# ---
#
# ### Day 60
#
# Production deployment review
#
# ---
#
# # Month 3 (Days 61-90)
#
# ## Goal: Interview Readiness + Ownership Skills
#
# ---
#
# # Week 9
#
# ## System Design Foundations
#
# ### Day 61
#
# Rate Limiter
#
# ---
#
# ### Day 62
#
# Notification System
#
# ---
#
# ### Day 63
#
# Chat Service
#
# ---
#
# ### Day 64
#
# Feed System
#
# ---
#
# ### Day 65
#
# Ticket Booking
#
# ---
#
# ### Day 66
#
# Distributed Cache
#
# ---
#
# ### Day 67
#
# Review all designs
#
# ---
#
# # Week 10
#
# ## Startup Engineering Scenarios
#
# ### Day 68
#
# Debug slow query incident
#
# ---
#
# ### Day 69
#
# Redis outage simulation
#
# ---
#
# ### Day 70
#
# RabbitMQ consumer lag
#
# ---
#
# ### Day 71
#
# Memory spike incident
#
# ---
#
# ### Day 72
#
# API latency incident
#
# ---
#
# ### Day 73
#
# Production postmortem writing
#
# ---
#
# ### Day 74
#
# Architecture review
#
# ---
#
# # Week 11
#
# ## AI-Assisted Engineering
#
# ### Day 75
#
# Study:
#
# * Cursor rules
# * AGENTS.md
#
# Build:
#
# * Repo rules
#
# ---
#
# ### Day 76
#
# Generate feature with AI
#
# Review thoroughly
#
# ---
#
# ### Day 77
#
# Generate tests with AI
#
# Audit them
#
# ---
#
# ### Day 78
#
# Generate refactor
#
# Review performance impact
#
# ---
#
# ### Day 79
#
# Prompt engineering for codebases
#
# ---
#
# ### Day 80
#
# Context architecture
#
# ---
#
# ### Day 81
#
# Full repository review
#
# ---
#
# # Week 12
#
# ## Interview Sprint
#
# ### Day 82
#
# Top 20 DSA patterns
#
# ---
#
# ### Day 83
#
# Top 20 SQL questions
#
# ---
#
# ### Day 84
#
# OS fundamentals review
#
# ---
#
# ### Day 85
#
# Networking review
#
# ---
#
# ### Day 86
#
# Database review
#
# ---
#
# ### Day 87
#
# Redis review
#
# ---
#
# ### Day 88
#
# RabbitMQ review
#
# ---
#
# ### Day 89
#
# Mock startup interview
#
# Questions:
#
# * Why RabbitMQ?
# * Why Redis?
# * How would you scale?
# * What failed in production?
#
# ---
#
# ### Day 90
#
# Final Deliverables
#
# Prepare:
#
# * Resume
# * GitHub
# * Architecture diagrams
# * Project walkthrough video
# * Deployment URL
# * Postmortem document
# * Performance report
#
# ---
#
# # What a Series A–C Startup Wants to See by Day 90
#
# If you finish this properly, you should be able to demonstrate:
#
# ✅ Go backend development
#
# ✅ PostgreSQL query optimization
#
# ✅ Redis caching strategies
#
# ✅ RabbitMQ event-driven systems
#
# ✅ Dockerized services
#
# ✅ Monitoring with Prometheus
#
# ✅ CI/CD pipelines
#
# ✅ Production deployment
#
# ✅ Basic system design
#
# ✅ Incident debugging
#
# ✅ AI-assisted development workflow
#
# That profile is significantly stronger than the average 0–2 YOE candidate who mostly has DSA + CRUD projects. It resembles someone who has already operated a real backend service and can contribute productively within a few weeks of joining a startup.
